# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/home/chengyuli/yanshan/data/DataScience/weibo_2.csv')
# df = df.dropna()
df.head()
# Out:
#                  id        bid     user_id        用户昵称  \
# 0  4984072646690371  Nzh72s4td  1659893422        小凡好摄
# 1  4984070330908966  Nzh3j3OsK  2095252841        潇洒友A
# 2  4984067722316096  NzgZ69Iwo  1659893422        小凡好摄
# 3  4984066299921205  NzgWNFCXr  5586933121  从宇宙黑洞飞出火凤凰
# 4  4984064538841564  NzgTXB65S  1656831930      总台环球资讯
#
#                                                 微博正文 头条文章url 发布位置 艾特用户  \
# 0  #巴以冲突#据当地记者：加沙地带中部努塞拉特，在以色列的袭击中，又有两名小女孩丧生。视频不打...     NaN  NaN  NaN
# 1  #巴以冲突#战乱中巴勒斯坦儿童惨不忍睹的真实录像。网友：这是巴基斯坦人民向世界血与泪的控诉。...     NaN  NaN  NaN
# 2  #巴以冲突#据外媒消息：以色列的犹太人创作了这座雕塑，并将其命名为“麦克耶稣”。#黄媒不会说...     NaN  NaN  NaN
# 3  【年终节目2023世界·选择】回望这一年，地区冲突延宕不止，地缘政治博弈日趋复杂，全球经济复...     NaN  NaN  NaN
# 4  【#视频回顾2023国际新闻大事件#】巴以冲突、中东迎来“和解潮”、毛伊岛大火、英国伯明翰“...     NaN  NaN  NaN
#
#                  话题  转发数  评论数  点赞数              发布时间   发布工具  \
# 0     巴以冲突,黄媒不会说的真相   22   17  128  2023-12-28 23:56  微博视频号
# 1    巴以冲突,以色列犹太复国主义   11    8   21  2023-12-28 23:47   牛博超话
# ...

# %%
df = df[['微博正文', '发布时间']]
df.rename(columns={
    '微博正文': 'contents',
    '发布时间': 'time'
}, inplace=True)
df.head()
# Out:
#                                             contents              time
# 0  #巴以冲突#据当地记者：加沙地带中部努塞拉特，在以色列的袭击中，又有两名小女孩丧生。视频不打...  2023-12-28 23:56
# 1  #巴以冲突#战乱中巴勒斯坦儿童惨不忍睹的真实录像。网友：这是巴基斯坦人民向世界血与泪的控诉。...  2023-12-28 23:47
# 2  #巴以冲突#据外媒消息：以色列的犹太人创作了这座雕塑，并将其命名为“麦克耶稣”。#黄媒不会说...  2023-12-28 23:36
# 3  【年终节目2023世界·选择】回望这一年，地区冲突延宕不止，地缘政治博弈日趋复杂，全球经济复...  2023-12-28 23:31
# 4  【#视频回顾2023国际新闻大事件#】巴以冲突、中东迎来“和解潮”、毛伊岛大火、英国伯明翰“...  2023-12-28 23:24

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91531 entries, 0 to 91530
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   contents  91531 non-null  object
#  1   time      91531 non-null  object
# dtypes: object(2)
# memory usage: 1.4+ MB

# %%
df.to_csv("/home/chengyuli/yanshan/data/DataScience/rawData/weibo_raw_2.csv", index=False)
