# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/home/chengyuli/yanshan/data/DataScience/weibo.csv')
# df = df.dropna()
df.head()
# Out:
#                  id        bid     user_id      用户昵称  \
# 0  4956532087720434  NnIEMwor8  2423228220      北京鲁戈
# 1  4956531999641404  NnIEDEsaw  1942328942    兌換糖漿來生
# 2  4956531838947310  NnIEnBxBs  6329798664  霈然EDWARD
# 3  4956531823740419  NnIEmfH3l  7514313063    我特么剁剁剁
# 4  4956531697386414  NnIE9uZxI  2310663307       肥唐说
#
#                                                 微博正文 头条文章url 发布位置 艾特用户  \
# 0                           #巴以冲突#再起敌对情结难解L北京鲁戈的微博视频     NaN  NaN  NaN
# 1                 好消息是：在最低点补仓了坏消息是：只补了一千更坏的消息是：巴以冲突了     NaN  NaN  NaN
# 2  一个所谓的“中以”混血，一个有中国血统的以色列籍女人喊话中国有义务救她的女儿，你咋不喊话你的...     NaN  NaN  NaN
# 3                  逃避了很久晚上刷到巴以冲突还是忍不住看了结果又哭崩溃了心里难受….     NaN  NaN  NaN
# 4  【家没了，我们只拥有这堆废墟！#巴勒斯坦男子流连在被毁家旁边#】巴以冲突中，一名巴勒斯坦男子...     NaN  NaN  NaN
#
#                                   话题  转发数  评论数  点赞数              发布时间  \
# 0                               巴以冲突   14   13   21  2023-10-14 00:00
# 1                                NaN    0    1    0  2023-10-13 23:59
# ...

# %%
df = df[['微博正文', '发布时间']]
df.rename(columns={
    '微博正文': 'contents',
    '发布时间': 'time'
}, inplace=True)
df.head()
# Out:
#                                             contents              time
# 0                           #巴以冲突#再起敌对情结难解L北京鲁戈的微博视频  2023-10-14 00:00
# 1                 好消息是：在最低点补仓了坏消息是：只补了一千更坏的消息是：巴以冲突了  2023-10-13 23:59
# 2  一个所谓的“中以”混血，一个有中国血统的以色列籍女人喊话中国有义务救她的女儿，你咋不喊话你的...  2023-10-13 23:59
# 3                  逃避了很久晚上刷到巴以冲突还是忍不住看了结果又哭崩溃了心里难受….  2023-10-13 23:58
# 4  【家没了，我们只拥有这堆废墟！#巴勒斯坦男子流连在被毁家旁边#】巴以冲突中，一名巴勒斯坦男子...  2023-10-13 23:58

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19999 entries, 0 to 19998
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   contents  19999 non-null  object
#  1   time      19999 non-null  object
# dtypes: object(2)
# memory usage: 312.6+ KB

# %%
df.to_csv("/home/chengyuli/yanshan/data/DataScience/rawData/weibo_raw.csv", index=False)
